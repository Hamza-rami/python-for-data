# %% [markdown]
# exircise:trending skills

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast

# import data
df = pd.read_csv("/goinfre/hrami/python_for_data/data_jobs.csv")

# data cleanup
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_da_pivot.iloc[:,:6].plot(kind="line")
plt.title('top 6 skills for Data analysts per month')
plt.ylabel('count')
plt.xlabel('Month')
plt.show()
